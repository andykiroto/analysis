# %%
#Load the required libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Load the data
df1 = pd.read_csv('C:/Users/GEORGE/Desktop/NSE analysis/NSE_data_all_stocks_2013.csv')
df2 = pd.read_csv('C:/Users/GEORGE/Desktop/NSE analysis/NSE_data_all_stocks_2014.csv')
df3 = pd.read_csv('C:/Users/GEORGE/Desktop/NSE analysis/NSE_data_all_stocks_2015.csv')
df4 = pd.read_csv('C:/Users/GEORGE/Desktop/NSE analysis/NSE_data_all_stocks_2016.csv')
df5 = pd.read_csv('C:/Users/GEORGE/Desktop/NSE analysis/NSE_data_all_stocks_2017.csv')
df6 = pd.read_csv('C:/Users/GEORGE/Desktop/NSE analysis/NSE_data_all_stocks_2018.csv')
df7 = pd.read_csv('C:/Users/GEORGE/Desktop/NSE analysis/NSE_data_all_stocks_2019.csv')
df8 = pd.read_csv('C:/Users/GEORGE/Desktop/NSE analysis/NSE_data_all_stocks_2020.csv')

# %%
df1.head()
# Out:
#        DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  2-Jan-13  EGAD              Eaagads Ltd     8.2       14      25       25
# 1  2-Jan-13  KUKZ               Kakuzi Plc     300    423.5    67.5     67.5
# 2  2-Jan-13  KAPC  Kapchorua Tea Kenya Plc      59       95     118      118
# 3  2-Jan-13  LIMT           Limuru Tea Plc     385      475     430      430
# 4  2-Jan-13  SASN               Sasini Plc    14.8     19.6    11.7    12.05
#
#   Day Price Previous Change Change%  Volume Adjust
# 0        25       25      -       -       -      -
# 1      67.5       72   -4.5   6.25%     300      -
# 2       118      118      -       -       -     59
# 3       430      430      -       -       -    215
# 4      11.9     11.7    0.2   1.71%  14,500      -

# %%
df8.head()
# Out:
#         DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  02-Jan-20  EGAD              Eaagads Ltd     8.2       14    10.1     10.1
# 1  02-Jan-20  KUKZ               Kakuzi Plc     300    423.5     340      340
# 2  02-Jan-20  KAPC  Kapchorua Tea Kenya Plc      59       95      80       80
# 3  02-Jan-20  LIMT           Limuru Tea Plc     385      475     450      450
# 4  02-Jan-20  SASN               Sasini Plc    14.8     19.6   16.15    16.15
#
#   Day Price Previous Change Change% Volume Adjust
# 0      10.1     10.1      -       -      -      -
# 1       340      340      -       -      -      -
# 2        80       80      -       -      -      -
# 3       450      450      -       -      -      -
# 4     16.15     16.9  -0.75   4.44%    300      -

# %%
# describes the data
df1.describe()
# Out:
#              DATE   CODE         NAME 12m Low 12m High Day Low Day High  \
# count       14889  14889        14889   14889    14889   14889    14889
# unique        247     62           62      90      101    1811     1807
# top     31-Dec-13   EGAD  Eaagads Ltd       2     55.5     5.5        3
# freq           62    247          247     476      494     269      273
#
#        Day Price Previous Change Change% Volume Adjust
# count      14889    14889  14889   14889  14889  14889
# unique      2146     2147    677     785   4443   1040
# top          5.5      5.5      -       -      -      -
# freq         262      262   5096    5099   3231  10521

# %%
# finding the correlation of data
df1.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#finding null values
df1.isnull().sum()
# Out:
# DATE         0
# CODE         0
# NAME         0
# 12m Low      0
# 12m High     0
# Day Low      0
# Day High     0
# Day Price    0
# Previous     0
# Change       0
# Change%      0
# Volume       0
# Adjust       0
# dtype: int64

# %%
# when values are null
df2.isnull().sum()
# Out:
# DATE         1
# CODE         1
# NAME         1
# 12m Low      1
# 12m High     1
# Day Low      1
# Day High     1
# Day Price    1
# Previous     1
# Change       1
# Change%      1
# Volume       1
# Adjust       1
# dtype: int64

# %%
#Replacing null values

df2.replace(np.nan,'0',inplace = True)

# %%
# check for changes
df2.isnull().sum()
# Out:
# DATE         0
# CODE         0
# NAME         0
# 12m Low      0
# 12m High     0
# Day Low      0
# Day High     0
# Day Price    0
# Previous     0
# Change       0
# Change%      0
# Volume       0
# Adjust       0
# dtype: int64

# %%
# identify if there is duplicated values
df1.duplicated().sum()
# Out:
# 0

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# show the panel data for 2013
df1 = pd.read_csv('C:/Users/GEORGE/Desktop/NSE analysis/NSE_data_all_stocks_2013.csv')
df1 = df1.loc[df1.NAME=='Sasini Plc', :]
df1.head()
# Out:
#          DATE  CODE        NAME 12m Low 12m High Day Low Day High Day Price  \
# 4    2-Jan-13  SASN  Sasini Plc    14.8     19.6    11.7    12.05      11.9
# 63   3-Jan-13  SASN  Sasini Plc    14.8     19.6    11.7    11.95     11.75
# 122  4-Jan-13  SASN  Sasini Plc    14.8       19   11.75       12      11.9
# 181  7-Jan-13  SASN  Sasini Plc    14.8     19.6    11.7    12.05        12
# 240  8-Jan-13  SASN  Sasini Plc    14.8     19.6      12    12.25      12.1
#
#     Previous Change Change%  Volume Adjust
# 4       11.7    0.2   1.71%  14,500      -
# 63      11.9  -0.15   1.26%   2,300      -
# 122    11.75   0.15   1.28%   1,900      -
# 181     11.9    0.1   0.84%  64,600      -
# 240       12    0.1   0.83%   5,600      -

# %%
# show the panel data for 2020
df8 = pd.read_csv('C:/Users/GEORGE/Desktop/NSE analysis/NSE_data_all_stocks_2020.csv')
df8 = df8.loc[df8.NAME=='Sasini Plc', :]
df8.head()
# Out:
#           DATE  CODE        NAME 12m Low 12m High Day Low Day High Day Price  \
# 4    02-Jan-20  SASN  Sasini Plc    14.8     19.6   16.15    16.15     16.15
# 75   03-Jan-20  SASN  Sasini Plc    14.8     19.6    16.9     17.5     17.15
# 146  06-Jan-20  SASN  Sasini Plc    14.8     19.6   16.15     16.5     16.25
# 217  07-Jan-20  SASN  Sasini Plc    14.8     19.6   16.55    17.75     17.35
# 288  08-Jan-20  SASN  Sasini Plc    14.8     19.6   16.55    16.55     16.55
#
#     Previous Change Change% Volume Adjust
# 4       16.9  -0.75   4.44%    300      -
# 75     16.15      1   6.19%  1,200      -
# 146    17.15   -0.9   5.25%  2,000      -
# 217    16.25    1.1   6.77%    300      -
# 288    17.35   -0.8   4.61%    100      -

# %%
df1.dtypes
# Out:
# DATE         object
# CODE         object
# NAME         object
# 12m Low      object
# 12m High     object
# Day Low      object
# Day High     object
# Day Price    object
# Previous     object
# Change       object
# Change%      object
# Volume       object
# Adjust       object
# dtype: object

# %%
df1['DATE']= pd.to_datetime(df1['DATE'])
df1.head()
# Out:
#           DATE  CODE        NAME 12m Low 12m High Day Low Day High Day Price  \
# 4   2013-01-02  SASN  Sasini Plc    14.8     19.6    11.7    12.05      11.9
# 63  2013-01-03  SASN  Sasini Plc    14.8     19.6    11.7    11.95     11.75
# 122 2013-01-04  SASN  Sasini Plc    14.8       19   11.75       12      11.9
# 181 2013-01-07  SASN  Sasini Plc    14.8     19.6    11.7    12.05        12
# 240 2013-01-08  SASN  Sasini Plc    14.8     19.6      12    12.25      12.1
#
#     Previous Change Change%  Volume Adjust
# 4       11.7    0.2   1.71%  14,500      -
# 63      11.9  -0.15   1.26%   2,300      -
# 122    11.75   0.15   1.28%   1,900      -
# 181     11.9    0.1   0.84%  64,600      -
# 240       12    0.1   0.83%   5,600      -

# %%
#data indexing trend display
# %matplotlib inline
df1.plot(grid='on')
# Out:
# <AxesSubplot:>
